# %% [markdown]
# 1. Demonstrate how to create simple and multi-line strings, and check whether a string can change after its creation.

# %%
# simple string

str1='Hello World'
str2="Hello World 2"

# %%
str1
# Out:
# 'Hello World'

# %%
str2
# Out:
# 'Hello World 2'

# %%
# Multi-line strings using triple quotes
str3=''' Every Flower Is a Soule
Blossoming in nature'''

# %%
str3
# Out:
# ' Every Flower Is a Soule\nBlossoming in nature'

# %%
#using \n
str4=("Every Flower Is a Soule \n"    
              "Blossoming in nature \n")

# %%
str4
# Out:
# 'Every Flower Is a Soule \nBlossoming in nature \n'

# %%
#using \n and \
str5=("Every Flower Is a Soule \n"  
              "Blossoming in nature \n")

# %%
str5
# Out:
# 'Every Flower Is a Soule \nBlossoming in nature \n'

# %% [markdown]
# 2. For a given string ‘Hello World!’, extract the following:
#
# *   H W
# *   o o
# *   llorld
# *   !dlroW olleH
# *   World!
# *   Hello

# %%
str22="Hello World!"

# %%
print(str22[0]+' '+str22[6])
print(str22[4]+' '+str22[7])
print(str22[2:4]+str22[7:11])
print(str22[ ::-1])
print(str22[6:])
print(str22[:5])
# Out:
# H W
# o o
# llorld
# !dlroW olleH
# World!
# Hello

# %% [markdown]
# 3. For the following strings, determine which contain only alphabets, only digits, alphanumeric, which are in lowercase, and which are in uppercase. Also check whether str3 begins or ends with the word “Now”.
#
# *   Str1 = ‘Welcome’
# *  Str2 = ‘Hello World!’
# *   Str3 = ‘Now is the best time ever! ‘
# *   Str4 = ‘500017’
# *   Str5 = ‘IPhone 6’

# %%
str1="Welcome"
str2="Hello World"
str3="Now is the best time ever!"
str4="500017"
str5="IPhone 6"

# %%
# str1="Welcome"
print("str1 is alpha",str1.isalpha())
print("str1 is numeric",str1.isnumeric())
print("str1 is alphanumeric",str1.isalnum())
print("str1 is lower",str1.islower())
print("str1 is upper",str1.isupper())
# Out:
# str1 is alpha True
# str1 is numeric False
# str1 is alphanumeric True
# str1 is lower False
# str1 is upper False

# %%
# Str2 = ‘Hello World!’
print("str2 is alpha",str2.isalpha())
print("str2 is numeric",str2.isnumeric())
print("str2 is alphanumeric",str2.isalnum())
print("str2 is lower",str2.islower())
print("str2 is upper",str2.isupper())
# Out:
# str2 is alpha False
# str2 is numeric False
# str2 is alphanumeric False
# str2 is lower False
# str2 is upper False

# %%
# Str3 = ‘Now is the best time ever! ‘
print("str3 is alpha",str3.isalpha())
print("str3 is numeric",str3.isnumeric())
print("str3 is alphanumeric",str3.isalnum())
print("str3 is lower",str3.islower())
print("str3 is upper",str3.isupper())
print("str3 is begins with Now",str3.startswith("Now"))
print("str3 is ends with Now",str3.endswith("Now"))
# Out:
# str3 is alpha False
# str3 is numeric False
# str3 is alphanumeric False
# str3 is lower False
# str3 is upper False
# str3 is begins with Now True
# str3 is ends with Now False

# %%
# Str4 = ‘500017’
print("str4 is numeric",str4.isnumeric())
print("str4 is alphanumeric",str4.isalnum())
print("str4 is upper",str4.isdigit())
# Out:
# str4 is numeric True
# str4 is alphanumeric True
# str4 is upper True

# %%
#Str5 = ‘IPhone 6’
print("str5 is numeric",str5.isnumeric())
print("str5 is alphanumeric",str5.isalnum())
print("str5 is upper",str5.isdigit())
# Out:
# str5 is numeric False
# str5 is alphanumeric False
# str5 is upper False

# %% [markdown]
# 4. Accept a sentence from the user. Convert the case of the input into title case.

# %%
txt1=input("Enter Text")
txt2=txt1.title()
print("title is :",txt2)
# Out:
# Enter Textswamy nath
# title is : Swamy Nath

# %% [markdown]
# 5. Write a program that reads an integer from the user. Then your program should display a message indicating whether the integer is even or odd.

# %%
x=int(input("Enter the Digit :"))
if x%2==0:
  print(x, "is the Even number")
else:
  print(x," is the Odd number")
print("The program is completed")
# Out:
# Enter the Digit :4
# 4 is the Even number
# The program is completed

# %% [markdown]
# 6. Create a program that reads a letter of the alphabet from the user. If the user enters a, e, i, o or u then your program should display a message indicating that the entered letter is a vowel. Otherwise, the program should display a message that the entered letter is a consonant

# %%
y=input("Enter the alphabet")

if y=="a" or y=="A" or y=="e" or y=="E" or y=="i" or y=="I" or y=="o" or y=="O" or y=="u" or y=="U":
  print(y, "is the a Vowel")
else:
  print(y," is the consonant")
# Out:
# Enter the alphabetA
# A is the a Vowel

# %% [markdown]
# 7. The length of a month varies from 28 to 31 days. Create a program that reads the name of a month from the user as a string. Then your program should display the number of days in that month. Display “28 or 29 days” for February so that leap years is addressed

# %%
# the month's has 31 days are : january,march,may,july,august,october,december.
# the month's haS 30 days are : apirl,june,september,november.
# the month's has 28 or 29 days are ; february
month=input("Entered the name of the month :")
if month=="january" or month=="march" or month=="may" or month=="july" or month=="august" or month=="october" or month=="december" :
  print(month, " has 31 day's")
elif month=="apirl" or month=="june" or month=="september" or month=="november":
  print(month, "has 30 day's")
else:
  print(month, " has 28 or 29 day's")
print("The program is completed")
# Out:
# Entered the name of the month :january
# january  has 31 day's
# The program is completed

# %% [markdown]
# 8. A triangle can be classified based on the lengths of its sides as equilateral, isosceles or scalene. All 3 sides of an equilateral triangle have the same length. An isosceles triangle has two sides that are the same length, and a third side that is a different length. If all of the sides have different lengths then the triangle is scalene. Write a program that reads the lengths of 3 sides of a triangle from the user. Display a message indicating the type of the triangle.

# %%
# equilateral triangle l1=l2=l3 (all sides are eual)
#Isoscles triangle has any two sides are equal (l1=l2!=l3 or l1=l3!=l2 or l1!=l2=l3)
# scalene triangle l1!=l2!=l3
l1=int(input("Enter the side-1 of the triangle  :"))
l2=int(input("Enter the side-2 of the triangle  :"))
l3=int(input("Enter the side-3 of the triangle  :"))
if l1==l2==l3:
    print("The triangle is equilateral with sides",l1,l2,l3)
elif l1==l2 or l2==l3 or l1==l3:
  print("The triangle is Isoscles triangle with sides",l1,l2,l3)
else:
  print("The entered triangle is scalene with sides",l1,l2,l3)
# Out:
# Enter the side-1 of the triangle  :10
# Enter the side-2 of the triangle  :10
# Enter the side-3 of the triangle  :10
# The triangle is equilateral with sides 10 10 10

# %% [markdown]
# 9. The rules for determining whether or not a year is a leap year follow:
#
# *   Any year that is divisible by 400 is a leap year.
# *   Of the remaining years, any year that is divisible by 100 is not a leap year.
#
# *   Of the remaining years, any year that is divisible by 4 is a leap year.
# *   All other years are not leap years.
# Write a program that reads a year from the user and displays a message indicating whether or not it is a leap year.

# %%
year=int(input('Enter a year :'))
if year%400==0:
   print(year,'Any year that is divisble by 400 is leap year')
elif year%100==0:
   print(year,'Of the remaining years, any year that is divisible by 100 is not a leap year')
elif year%4==0:
   print(year,'the remaining years, any year that is divisible by 4 is a leap year')
else:
   print(year,('All other years are not leap years'))
# Out:
# Enter a year :2000
# 2000 Any year that is divisble by 400 is leap year

# %% [markdown]
# 10. Write a program that computes the real roots of a quadratic function. Your program should begin by prompting the user for the values of a, b and c. Then it should display a message indicating the number of real roots, along with the values of the real roots (if any).

# %%
a=int(input("Enter the value of a is :"))
b=int(input("Enter the value of b is :"))
c=int(input("Enter the value of c is :"))

x1=(((-b)+((b**2)-(4*a*c)))/(2*a))
x2=(((-b)-((b**2)-(4*a*c)))/(2*a))

if x1!=x2:
  print(x1," and ",x2, " are the roots of quadratic euation ")
else:
  print(x1, " is the root of quadratic euation ")



#((a(x**2))+(b*x)+c)==0
# Out:
# Enter the value of a is :2
# Enter the value of b is :-3
# Enter the value of c is :4
# -5.0  and  6.5  are the roots of quadratic euation
