# %% [markdown]
# 1. Write a program to accept an integer n greater than 10. Then print all the odd numbers from 1 to n.

# %%
n=int(input("Enter the value of n greater than 10 :"))
if n>=10:
  a=1
  for i in range(1,n+1):
    if (a%2)!=0:
      print(a, "is an odd number")
    a+=1
else:
  print("Entered value is incorrect")
# Out:
# Enter the value of n greater than 10 :11
# 1 is an odd number
# 3 is an odd number
# 5 is an odd number
# 7 is an odd number
# 9 is an odd number
# 11 is an odd number

# %% [markdown]
# 2.Write a program to accept an integer n greater than 10. Then print all the prime numbers from 1 to n.

# %%
n=int(input("Enter the value of n greater than 10 :"))
if n>=10:
  for num in range (2,n+1):
    for i in range(2,num):
      if (num%i)==0:
        break
    else:
      print(num)
    num+=1
# Out:
# Enter the value of n greater than 10 :11
# 2
# 3
# 5
# 7
# 11

# %% [markdown]
# 3. In this exercise you will create a program that computes the average of a collection of values entered by the user. The user will enter 0 as a sentinel value to indicate that no further values will be provided. Your program should display an appropriate error message if the first value entered by the user is 0.

# %%
n=int(input("Emter the value of no.of numbers :"))
if n==0:
  print("Entered value is invalid")
else:
  sum=0
  for i in range(1,n+1):
    num=int(input("Enter the Number :"))
    sum+=num
  avg=(sum)/n
  print("The sum of the numbers is :",sum)
  print("The Avg of the numbers is :",avg)
# Out:
# Emter the value of no.of numbers :5
# Enter the Number :4
# Enter the Number :3
# Enter the Number :2
# Enter the Number :1
# Enter the Number :0
# The sum of the numbers is : 10
# The Avg of the numbers is : 2.0

# %% [markdown]
# 4. Write a program that takes a number as input and prints its multiplication table.

# %%
n=int(input("Enter the number :"))
m=int(input("Enter the number of multiplications :"))
for i in range(1,m+1):
  print(n, "*", i, "=",i*n)
# Out:
# Enter the number :5
# Enter the number of multiplications :10
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50

# %% [markdown]
# 5. Write a program that displays a temperature conversion table for degrees Celsius and degrees Fahrenheit. The table should include rows for all temperatures between 0 and 100 degrees Celsius that are multiples of 10 degrees Celsius. Include appropriate headings on your columns.

# %%
# Fs = [9 * C / 5 + 32 -----> celsius to fahrenheit
print("Fs         c")
for c in range(0,100,10):
  i+=1
  fs=(((9*c)/5)+32)
  print(f"{fs}      {c}")
# Out:
# Fs         c
# 32.0      0
# 50.0      10
# 68.0      20
# 86.0      30
# 104.0      40
# 122.0      50
# 140.0      60
# 158.0      70
# 176.0      80
# 194.0      90

# %% [markdown]
# 6. A string is a palindrome if it is identical forward and backward. For example “anna”, “civic”, “level” and “madam” are all examples of palindrome words. Write a program that reads a string from the user and uses a loop to determine whether or not it is a palindrome. Display the result, including a meaningful output message.

# %%
str1=input("Enter the string is : ")
rev=str1[::-1]
if str1==rev:
  print(str1,"Is the palindrome")
else:
  print(str1,"Is not a palindrome")
# Out:
# Enter the string is : civic
# civic Is the palindrome

# %% [markdown]
# 7. The greatest common divisor (GCD) of two positive integers, n and m, is the largest number, d, which divides evenly into both n and m. The following algorithm is used to find GCD of n and m :
#
# Initialize d to the smaller of m and n.
#
# While d does not evenly divide m or d does not evenly divide n do
#
# Decrease the value of d by 1
#
# Report d as the greatest common divisor of n and m
#
# Write a program that reads two positive integers from the user and uses this algorithm to determine and report their greatest common divisor.

# %%
m=int(input("Enter the values of m  is : "))
n=int(input("Enter the values of n  is : "))
f=1
if n>m:
  d=m
  e=n
else:
  d=n
  e=m
for i in range(1,d-1):
  if (d%i)==0:
    if (e%i)==0:
      f*=i
      d=d//i
print("The GCD of {} and {} is {}".format(m,n,f))
# Out:
# Enter the values of m  is : 18
# Enter the values of n  is : 24
# The GCD of 18 and 24 is 6

# %% [markdown]
# 8. The prime factorization of an integer, n, can be determined using the following steps:
#
# Initialize factor to two
#
# While factor is less than or equal to n do
#
# If n is evenly divisible by factor then
#
#            Conclude that factor is a factor of n
#
#            Divide n by factor using integer division
#
# Else
#
# Increase factor by one
#
# Write a program that reads an integer from the user. If the value entered by the user is less than 2 then your program should display an appropriate error message. Otherwise your program should display the prime numbers that can be multiplied together to compute n, with one factor appearing on each line.

# %%
mini_limit=int(input("Enter the mini_limit limit is :"))
max_limit=int(input("Enter the maximum limit (n) is :"))
if max_limit < 2:
    print("Enterd max_limit should be greater than 2")
elif max_limit < mini_limit:
    print("max_limit should be grater than mini_limit")
elif max_limit > mini_limit:
    print("The prime numbers are :")
    for n in range(mini_limit,max_limit+1):
        if n%2 != 0:
            factor=0
            for i in range(1,n+1):
                if n%i == 0:
                    factor+=1
                continue
            if factor==2 or factor==1:
                print(n)
        elif n==2:
            print(n)
else:
    print("No prime numbrs between you'r entered values")
# Out:
# Enter the mini_limit limit is :5
# Enter the maximum limit (n) is :20
# The prime numbers are :
# 5
# 7
# 11
# 13
# 17
# 19

# %% [markdown]
# 9. Write a program that converts a binary (base 2) number to decimal (base 10). Your program should begin by reading the binary number from the user as a string. Then it should compute the equivalent decimal number by processing each digit in the binary number. Finally, your program should display the equivalent decimal number with an appropriate message.

# %%
n=input("Entred the Binary numbr is :")  # remainder=dividend-quotint*divisor
q=0
for rem in n:
    r=int(rem)
    d=2*q+r
    q=d
print(n, "Binary number for",d," Decimal number")
# Out:
# Entred the Binary numbr is :1110
# digit : 1
# digit : 1
# digit : 1
# digit : 0
# 1110 Binary number for 14  Decimal number

# %% [markdown]
# 10. Demonstrate the formatting capabilities of format function on integers, floats and strings.

# %%
# 1
name,age,marks="swamy",21,43.524
print(f"student name={name}  age={age}  marks={marks}")
# Out:
# student name=swamy  age=21  marks=43.524

# %%
print("student name={}  age={}  marks={}".format(name,age,marks))
# Out:
# student name=swamy  age=21  marks=43.524

# %%
print("student name={1}  age={0}  marks={2}".format(22,"shiva",67.243))
# Out:
# student name=shiva  age=22  marks=67.243

# %%
print("{} and {}".format(234.4321,123.987))
# Out:
# 234.4321 and 123.987

# %%
print("{1:.2f} and {1:.2f}".format(234.4321,123.987))
# Out:
# 123.99 and 123.99

# %%
print("{:20} and {:20}".format(234.4321,123.987))
# Out:
#             234.4321 and              123.987
